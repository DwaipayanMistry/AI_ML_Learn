# %% [markdown]
# ## Reading data from various sources

# %%
import pandas as pd
from io import StringIO

# %%
Data= '{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile": [{"title1":"Team Lead", "title2":"Sr. Developer"}]}'
df_json=pd.read_json(StringIO(Data))
df_json
# Out:
#    employee_name                    email  \
# 0  James Madason  james.madason@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Develop...

# %%
df_json.to_json()
# Out:
# '{"employee_name":{"0":"James Madason"},"email":{"0":"james.madason@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Sr. Developer"}}}'

# %%
df_json.to_json(orient='records')
# Out:
# '[{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}]'

# %%
Data1= '{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile": {"title1":"Team Lead", "title2":"Sr. Developer"}}'

# %%
Data1
# Out:
# '{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile": {"title1":"Team Lead", "title2":"Sr. Developer"}}'

# %%
df_json1= pd.read_json(Data1)
df_json1
# Out:
# /tmp/ipykernel_143002/1395862569.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json1= pd.read_json(Data1)
#         employee_name                    email    job_profile
# title1  James Madason  james.madason@gmail.com      Team Lead
# title2  James Madason  james.madason@gmail.com  Sr. Developer

# %%
df_json1.to_json(orient='records')
# Out:
# '[{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile":"Team Lead"},{"employee_name":"James Madason","email":"james.madason@gmail.com","job_profile":"Sr. Developer"}]'

# %%
df_csv=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')
df_csv.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
df_csv1=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',header='infer')
df_csv1.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
df_csv1.to_csv('wine.csv')

# %%
url= 'https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/'
df_html= pd.read_html(url)
df_html
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
df_html[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
df_html0=df_html[0]

# %%
df_html0
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
import requests

# %%
url_Mobile_Code="https://en.wikipedia.org/wiki/Mobile_country_code"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}
response = requests.get(url_Mobile_Code, headers=headers)
html_content = response.content

df_html_Mob_Code= pd.read_html(html_content,match='Country', header=0)

# %%
df_html_Mob_Code
# Out:
# [     Mobile country code                                    Country ISO 3166  \
#  0                    289                                 A Abkhazia    GE-AB
#  1                    412                                Afghanistan       AF
#  2                    276                                    Albania       AL
#  3                    603                                    Algeria       DZ
#  4                    544  American Samoa (United States of America)       AS
#  ..                   ...                                        ...      ...
#  247                  452                                    Vietnam       VN
#  248                  543                        W Wallis and Futuna       WF
#  249                  421                                    Y Yemen       YE
#  250                  645                                   Z Zambia       ZM
#  251                  648                                   Zimbabwe       ZW
#
# ...

# %%
df_html_Mob_Code[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
df_html_Mob_Code=pd.DataFrame(df_html_Mob_Code[0])
df_html_Mob_Code
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
df_html_Mob_Code.dtypes
# Out:
# Mobile country code        int64
# Country                   object
# ISO 3166                  object
# Mobile network codes      object
# National MNC authority    object
# Remarks                   object
# dtype: object

# %%
sr_mobile_code= pd.Series(df_html_Mob_Code.iloc[0])
sr_mobile_code
# Out:
# Mobile country code                                            289
# Country                                                 A Abkhazia
# ISO 3166                                                     GE-AB
# Mobile network codes      List of mobile network codes in Abkhazia
# National MNC authority                                         NaN
# Remarks                                   MCC is not listed by ITU
# Name: 0, dtype: object

# %%
df_html_Mob_Code.loc[0][1]
# Out:
# /tmp/ipykernel_143002/1103420243.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_html_Mob_Code.loc[0][1]
# 'A Abkhazia'

# %%
# !pip install openpyxl

# %%
df_excel=pd.read_excel('data.xlsx')
df_excel
# Out:
#     Name  Age
# 0  Krish   32
# 1   Jack   34
# 2   John   31

# %%
df_excel.to_pickle('df_excel_pickle')

# %%
df_pickle= pd.read_pickle('df_excel_pickle')

# %%
df_pickle
# Out:
#     Name  Age
# 0  Krish   32
# 1   Jack   34
# 2   John   31
